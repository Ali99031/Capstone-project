# %%
import pandas as pd

# %%
car_df = pd.read_csv('cars.csv')

# %%
car_df.head()
# Out:
#          ID                                               Name   Price  \
# 0  11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1  12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2  12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3  12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4  12363884                       2016 Holden Cruze CD JH MY16   15990
#
#            Brand    Model               Variant    Series  Year  Kilometers  \
# 0         Toyota    Rukus               Build 2   AZE151R  2010      263000
# 1  Mercedes-Benz        V  250 D Avantgarde MWB  447 MY21  2021          19
# 2  Mercedes-Benz  Valente       116 CDI MWB RWD  447 MY21  2021          24
# 3  Mercedes-Benz     E250        CDI Avantgarde       207  2010      120579
# 4         Holden    Cruze                    CD   JH MY16  2016       72506
#
#           Type    Gearbox             Fuel         Status    CC  Color  \
# ...

# %%
car_df.dtypes
# Out:
# ID                   int64
# Name                object
# Price                int64
# Brand               object
# Model               object
# Variant             object
# Series              object
# Year                 int64
# Kilometers           int64
# Type                object
# Gearbox             object
# Fuel                object
# Status              object
# CC                   int64
# Color               object
# Seating Capacity     int64
# dtype: object

# %%
car_df.isnull().sum()
# Out:
# ID                  0
# Name                0
# Price               0
# Brand               0
# Model               0
# Variant             0
# Series              0
# Year                0
# Kilometers          0
# Type                0
# Gearbox             0
# Fuel                0
# Status              0
# CC                  0
# Color               0
# Seating Capacity    0
# dtype: int64

# %%
car_df.describe()
# Out:
#                  ID          Price          Year    Kilometers            CC  \
# count  1.704800e+04   17048.000000  17048.000000  1.704800e+04  17048.000000
# mean   1.279027e+07   36777.778038   2015.481288  1.032314e+05   2491.830303
# std    5.051111e+04   30305.015328      4.721591  8.041313e+04    881.985562
# min    1.153013e+07    1000.000000   1989.000000  1.000000e+00    875.000000
# 25%    1.275715e+07   18800.000000   2013.000000  4.450225e+04   1987.000000
# 50%    1.280207e+07   29990.000000   2016.000000  8.845400e+04   2354.000000
# 75%    1.283131e+07   45990.000000   2019.000000  1.488735e+05   2981.000000
# max    1.285246e+07  999000.000000   2022.000000  2.700000e+06   7300.000000
#
#        Seating Capacity
# count      17048.000000
# mean           5.115849
# std            1.121791
# min            2.000000
# 25%            5.000000
# 50%            5.000000
# 75%            5.000000
# max           14.000000

# %%
car_df['Fuel'].unique()
# Out:
# array(['Unleaded Petrol', 'Diesel', 'Premium Unleaded Petrol',
#        'Premium Unleaded/Electric', 'Unleaded Petrol/Electric',
#        'Liquid Petroleum Gas', 'Diesel/Electric'], dtype=object)

# %%
car_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17043    False
# 17044    False
# 17045    False
# 17046    False
# 17047    False
# Length: 17048, dtype: bool

# %%
car_df.duplicated().sum()
# Out:
# 0

# %%
car_df.drop_duplicates()
# Out:
#              ID                                               Name   Price  \
# 0      11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1      12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2      12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3      12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4      12363884                       2016 Holden Cruze CD JH MY16   15990
# ...         ...                                                ...     ...
# 17043  12852453                 2003 Holden Commodore Executive VY    4499
# 17044  12852460                        2008 Toyota Yaris YR NCP90R    4999
# 17045  12852462               2002 Holden Jackaroo SE LWB (4X4) U8    7999
# 17046  12852463               2016 Hyundai I30 Active GD4 Series 2   14000
# 17047  12852464              2005 Toyota RAV4 Cruiser (4X4) ACA23R    5999
#
# ...

# %%
car_df
# Out:
#              ID                                               Name   Price  \
# 0      11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1      12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2      12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3      12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4      12363884                       2016 Holden Cruze CD JH MY16   15990
# ...         ...                                                ...     ...
# 17043  12852453                 2003 Holden Commodore Executive VY    4499
# 17044  12852460                        2008 Toyota Yaris YR NCP90R    4999
# 17045  12852462               2002 Holden Jackaroo SE LWB (4X4) U8    7999
# 17046  12852463               2016 Hyundai I30 Active GD4 Series 2   14000
# 17047  12852464              2005 Toyota RAV4 Cruiser (4X4) ACA23R    5999
#
# ...

# %%
car_df['Seating Capacity'].head()
# Out:
# 0    5
# 1    7
# 2    8
# 3    4
# 4    5
# Name: Seating Capacity, dtype: int64

# %%
car_df[car_df['Kilometers'] == 2700000]
# Out:
#              ID                           Name  Price   Brand  Model  \
# 16662  12849595  2004 Holden Rodeo LT (4X4) RA  11000  Holden  Rodeo
#
#         Variant Series  Year  Kilometers             Type Gearbox  \
# 16662  LT (4X4)     RA  2004     2700000  Crew Cab Pickup  Manual
#
#                   Fuel Status    CC  Color  Seating Capacity
# 16662  Unleaded Petrol   Used  3494  White                 5

# %%
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt

# %%
car_df
# Out:
#              ID                                               Name   Price  \
# 0      11530130                  2010 Toyota Rukus Build 2 AZE151R    9999
# 1      12190570  2021 Mercedes-Benz V 250 D Avantgarde MWB 447 ...  117990
# 2      12321855  2021 Mercedes-Benz Valente 116 CDI MWB RWD 447...   79990
# 3      12346971         2010 Mercedes-Benz E250 CDI Avantgarde 207   34990
# 4      12363884                       2016 Holden Cruze CD JH MY16   15990
# ...         ...                                                ...     ...
# 17043  12852453                 2003 Holden Commodore Executive VY    4499
# 17044  12852460                        2008 Toyota Yaris YR NCP90R    4999
# 17045  12852462               2002 Holden Jackaroo SE LWB (4X4) U8    7999
# 17046  12852463               2016 Hyundai I30 Active GD4 Series 2   14000
# 17047  12852464              2005 Toyota RAV4 Cruiser (4X4) ACA23R    5999
#
# ...

# %%
pivot_df = car_df.pivot_table(
    index='CC',
    columns='Seating Capacity',
    values='Price',
    aggfunc='mean'
)

# %%
correlation_matrix = pivot_df.corr()

# %%
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", mask=mask)
plt.title('')
plt.show()

# %%
pivot_df = car_df.pivot_table(index='', columns='CC', values='Price')

# %%
correlation_matrix = pivot_df.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
Variant = car_df[['Variant','Brand','Model']]

# %%
Variant
# Out:
#                     Variant          Brand      Model
# 0                   Build 2         Toyota      Rukus
# 1      250 D Avantgarde MWB  Mercedes-Benz          V
# 2           116 CDI MWB RWD  Mercedes-Benz    Valente
# 3            CDI Avantgarde  Mercedes-Benz       E250
# 4                        CD         Holden      Cruze
# ...                     ...            ...        ...
# 17043             Executive         Holden  Commodore
# 17044                    YR         Toyota      Yaris
# 17045          SE LWB (4X4)         Holden   Jackaroo
# 17046                Active        Hyundai        I30
# 17047         Cruiser (4X4)         Toyota       RAV4
#
# [17048 rows x 3 columns]

# %%
Variant.to_csv('Variant.csv')
